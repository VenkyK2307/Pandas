# %%
import pandas as pd
pd.DataFrame({"Tes" : [56,43], "NO": [34,56]}, index = ["one", "three" ])
# Out:
#        Tes  NO
# one     56  34
# three   43  56

# %%
pd.Series([1,2,3,4,5], index= [20,21,22,23,34], name ="Table")
# Out:
# 20    1
# 21    2
# 22    3
# 23    4
# 34    5
# Name: Table, dtype: int64

# %% [markdown]
# ##Imporoting a CSV

# %%
data = pd.read_csv("/content/main.csv")
data
# Out:
#            Name    Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0      RELIANCE  16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# 1           TCS  14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# 2      HDFCBANK  12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# 3    BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# 4     ICICIBANK   8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ..          ...           ...     ...   ...     ...   ...      ...    ...
# 495      VIPIND      4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# 496   BALAMINES      4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# 497  RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# 498       SPARC      4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# 499  EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#     Capability  b  c  d  e  f  g
# 0            M  5  1  4  3  5  5
# ...

# %%
data.shape
# Out:
# (500, 15)

# %%
data.head()
# Out:
#          Name    Market Cap  Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0    RELIANCE  16,45,671.87  -4.86     1   12.69   0.5    13.70     23
# 1         TCS  14,14,726.49   -4.4  0.61   12.27  0.09    34.21     23
# 2    HDFCBANK  12,98,771.00  -5.15   1.1    6.46     0    23.11     21
# 3  BHARTIARTL  10,26,583.48  23.02  0.64   26.47  2.04    25.54     26
# 4   ICICIBANK   8,82,070.18   7.85  1.27   18.21     0    18.26     26
#
#   Capability  b  c  d  e  f  g
# 0          M  5  1  4  3  5  5
# 1          M  5  1  4  3  5  5
# 2          M  5  1  3  2  5  5
# 3          S  5  5  4  5  2  5
# 4          S  4  5  3  4  5  5

# %% [markdown]
# **#LECTURE 2**

# %%
data.Name
# Out:
# 0        RELIANCE
# 1             TCS
# 2        HDFCBANK
# 3      BHARTIARTL
# 4       ICICIBANK
#           ...
# 495        VIPIND
# 496     BALAMINES
# 497    RAJESHEXPO
# 498         SPARC
# 499    EASEMYTRIP
# Name: Name, Length: 500, dtype: object

# %%
data['Name']
# Out:
# 0        RELIANCE
# 1             TCS
# 2        HDFCBANK
# 3      BHARTIARTL
# 4       ICICIBANK
#           ...
# 495        VIPIND
# 496     BALAMINES
# 497    RAJESHEXPO
# 498         SPARC
# 499    EASEMYTRIP
# Name: Name, Length: 500, dtype: object

# %%
data['Name'][0]
# Out:
# 'RELIANCE'

# %%
data.iloc[10]

#Pulling out the 10th Row
# Out:
# Name                 LICI
# Market Cap    4,96,385.82
# Alpha               -7.56
# Beta                    -
# 5Y CAGR                 -
# D/E                     0
# EPS (Q)              17.4
# SCORE                  21
# Capability              M
# b                       4
# c                       1
# d                       1
# e                       5
# f                       5
# g                       5
# Name: 10, dtype: object

# %%
data.loc[10, "Name"]
# Out:
# 'LICI'

# %% [markdown]
# ##Returns out only the required colums

# %%
data.loc[:,["Name" ,"b","c"]]
#Seperating out certain colums of the data
# Out:
#            Name  b  c
# 0      RELIANCE  5  1
# 1           TCS  5  1
# 2      HDFCBANK  5  1
# 3    BHARTIARTL  5  5
# 4     ICICIBANK  4  5
# ..          ... .. ..
# 495      VIPIND  1  1
# 496   BALAMINES  1  1
# 497  RAJESHEXPO  1  1
# 498       SPARC  1  1
# 499  EASEMYTRIP  1  1
#
# [500 rows x 3 columns]

# %%
data
# Out:
#            Name    Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0      RELIANCE  16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# 1           TCS  14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# 2      HDFCBANK  12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# 3    BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# 4     ICICIBANK   8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ..          ...           ...     ...   ...     ...   ...      ...    ...
# 495      VIPIND      4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# 496   BALAMINES      4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# 497  RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# 498       SPARC      4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# 499  EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#     Capability  b  c  d  e  f  g
# 0            M  5  1  4  3  5  5
# ...

# %%
data.set_index("Name")
#Setting index as NAME
# Out:
#               Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# Name
# RELIANCE    16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# TCS         14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# HDFCBANK    12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# ICICIBANK    8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ...                  ...     ...   ...     ...   ...      ...    ...
# VIPIND          4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# BALAMINES       4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# SPARC           4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#            Capability  b  c  d  e  f  g
# Name
# RELIANCE            M  5  1  4  3  5  5
# TCS                 M  5  1  4  3  5  5
# ...

# %%
two =data.Capability  == "M"
two.sum()
# Out:
# 270

# %% [markdown]
# #Selecting a particular Catagory

# %%
count = data.loc[data.Capability == "M"]
count

#Takes out the Values whose capability is "M"
#count.Name gives out only country names
# Out:
#            Name    Market Cap  Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0      RELIANCE  16,45,671.87  -4.86     1   12.69   0.5    13.70     23
# 1           TCS  14,14,726.49   -4.4  0.61   12.27  0.09    34.21     23
# 2      HDFCBANK  12,98,771.00  -5.15   1.1    6.46     0    23.11     21
# 5          INFY   7,63,490.30  -3.65  0.81    18.4  0.09    16.43     23
# 6          SBIN   6,49,399.98   2.64   1.3   17.32     0    21.12     24
# ..          ...           ...    ...   ...     ...   ...      ...    ...
# 475    DBREALTY      7,497.59  16.17  0.82   72.18  0.42     0.08     22
# 477  CHENNPETRO      7,471.63  58.43  1.13    34.3  0.25     1.40     22
# 479  EQUITASBNK      7,252.17   5.47   0.8       -     0     0.58     22
# 489        GPPL      6,514.84   6.91  0.67   10.73  0.03     2.06     21
# 494        GAEL      5,200.41   5.17  0.73   24.31  0.07     1.56     23
#
#     Capability  b  c  d  e  f  g
# 0            M  5  1  4  3  5  5
# ...

# %%
import pandas as pd

data =pd.read_csv("/content/main.csv", index_col = 0)

# %%
data.isnull().sum()
#to count no.of nulls in each column
# Out:
# Name          0
# Market Cap    0
# Alpha         0
# Beta          0
# 5Y CAGR       0
# D/E           0
# EPS (Q)       0
# SCORE         0
# Capability    0
# b             0
# c             0
# d             0
# e             0
# f             0
# g             0
# dtype: int64

# %%
data
# Out:
#               Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# Name
# RELIANCE    16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# TCS         14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# HDFCBANK    12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# ICICIBANK    8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ...                  ...     ...   ...     ...   ...      ...    ...
# VIPIND          4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# BALAMINES       4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# SPARC           4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#            Capability  b  c  d  e  f  g
# Name
# RELIANCE            M  5  1  4  3  5  5
# TCS                 M  5  1  4  3  5  5
# ...

# %%
data.c.describe()
#Gives info about the column in integers
# Out:
# count    500.00000
# mean       3.87000
# std        1.67891
# min        1.00000
# 25%        2.00000
# 50%        5.00000
# 75%        5.00000
# max        5.00000
# Name: c, dtype: float64

# %%
data.Alpha.describe()
# Out:
# count     500
# unique    465
# top         -
# freq       27
# Name: Alpha, dtype: object

# %%
data.c.mean()
#Finding the mean of the c column
#data.c.describe()
# Out:
# 3.87

# %%
data.Capability.unique()
##Shows the type of unique Values
# Out:
# array(['M', 'S', 'R', 'HR'], dtype=object)

# %%
data.Capability.value_counts()
#Count of Each Section
# Out:
# Capability
# M     270
# R     113
# HR     61
# S      56
# Name: count, dtype: int64

# %%
r_mean = data.c.mean()
r_mean
data.c.map(lambda p : p-r_mean)

#Finding the dIfference between the mean to the numbers in the column
# Out:
# Name
# RELIANCE     -2.87
# TCS          -2.87
# HDFCBANK     -2.87
# BHARTIARTL    1.13
# ICICIBANK     1.13
#               ...
# VIPIND       -2.87
# BALAMINES    -2.87
# RAJESHEXPO   -2.87
# SPARC        -2.87
# EASEMYTRIP   -2.87
# Name: c, Length: 500, dtype: float64

# %%
data.head()
# Out:
#               Market Cap  Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# Name
# RELIANCE    16,45,671.87  -4.86     1   12.69   0.5    13.70     23
# TCS         14,14,726.49   -4.4  0.61   12.27  0.09    34.21     23
# HDFCBANK    12,98,771.00  -5.15   1.1    6.46     0    23.11     21
# BHARTIARTL  10,26,583.48  23.02  0.64   26.47  2.04    25.54     26
# ICICIBANK    8,82,070.18   7.85  1.27   18.21     0    18.26     26
#
#            Capability  b  c  d  e  f  g
# Name
# RELIANCE            M  5  1  4  3  5  5
# TCS                 M  5  1  4  3  5  5
# HDFCBANK            M  5  1  3  2  5  5
# BHARTIARTL          S  5  5  4  5  2  5
# ICICIBANK           S  4  5  3  4  5  5

# %%
data.loc[:, ["Beta", "Market Cap"]]

# List out onlt required coumns
# Out:
#             Beta    Market Cap
# Name
# RELIANCE       1  16,45,671.87
# TCS         0.61  14,14,726.49
# HDFCBANK     1.1  12,98,771.00
# BHARTIARTL  0.64  10,26,583.48
# ICICIBANK   1.27   8,82,070.18
# ...          ...           ...
# VIPIND      1.17      4,977.79
# BALAMINES   2.03      4,912.64
# RAJESHEXPO   0.5      4,872.38
# SPARC       1.53      4,687.39
# EASEMYTRIP   1.5      4,337.96
#
# [500 rows x 2 columns]

# %%
data.Alpha + " AND " + data.Beta

#Adjoining the data of alpha and Beta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f449562c20d0> in <cell line: 0>()
# ----> 1 data.Alpha + " AND " + data.Beta
#       2
#       3 #Adjoining the data of alpha and Beta
#
# NameError: name 'data' is not defined

# %%
data.d.value_counts()
# Out:
# d
# 3    177
# 4    162
# 2     67
# 1     63
# 5     31
# Name: count, dtype: int64

# %%
data.groupby("c").c.count()

#Gives same result as of
#"data.c.value_counts()" but it gives in order
# Out:
# c
# 1    106
# 2     27
# 3     23
# 4     14
# 5    330
# Name: c, dtype: int64

# %%
data.c.dtype
# Out:
# dtype('int64')

# %%
data
# Out:
#               Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# Name
# RELIANCE    16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# TCS         14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# HDFCBANK    12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# ICICIBANK    8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ...                  ...     ...   ...     ...   ...      ...    ...
# VIPIND          4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# BALAMINES       4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# SPARC           4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#            Capability  b  c  d  e  f  g
# Name
# RELIANCE            M  5  1  4  3  5  5
# TCS                 M  5  1  4  3  5  5
# ...

# %%
data =pd.read_csv("/content/main.csv")
data
# Out:
#            Name    Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0      RELIANCE  16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# 1           TCS  14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# 2      HDFCBANK  12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# 3    BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# 4     ICICIBANK   8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ..          ...           ...     ...   ...     ...   ...      ...    ...
# 495      VIPIND      4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# 496   BALAMINES      4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# 497  RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# 498       SPARC      4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# 499  EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#     Capability  b  c  d  e  f  g
# 0            M  5  1  4  3  5  5
# ...

# %%
data.Name.replace("TCS","TATA")

#Replace Attribute with another
# Out:
# 0        RELIANCE
# 1            TATA
# 2        HDFCBANK
# 3      BHARTIARTL
# 4       ICICIBANK
#           ...
# 495        VIPIND
# 496     BALAMINES
# 497    RAJESHEXPO
# 498         SPARC
# 499    EASEMYTRIP
# Name: Name, Length: 500, dtype: object

# %%
pd.read_csv("/content/main.csv")
# Out:
#            Name    Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0      RELIANCE  16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# 1           TCS  14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# 2      HDFCBANK  12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# 3    BHARTIARTL  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# 4     ICICIBANK   8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ..          ...           ...     ...   ...     ...   ...      ...    ...
# 495      VIPIND      4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# 496   BALAMINES      4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# 497  RAJESHEXPO      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# 498       SPARC      4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# 499  EASEMYTRIP      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#     Capability  b  c  d  e  f  g
# 0            M  5  1  4  3  5  5
# ...

# %%
data.rename(columns={"Name":"Company"})

#Replaces the Name with the company
# Out:
#            Company    Market Cap   Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0        RELIANCE1  16,45,671.87   -4.86     1   12.69   0.5    13.70     23
# 1             TCS2  14,14,726.49    -4.4  0.61   12.27  0.09    34.21     23
# 2        HDFCBANK3  12,98,771.00   -5.15   1.1    6.46     0    23.11     21
# 3      BHARTIARTL4  10,26,583.48   23.02  0.64   26.47  2.04    25.54     26
# 4       ICICIBANK5   8,82,070.18    7.85  1.27   18.21     0    18.26     26
# ..             ...           ...     ...   ...     ...   ...      ...    ...
# 495      VIPIND496      4,977.79  -21.61  1.17   -5.63  1.29    -0.88     10
# 496   BALAMINES497      4,912.64  -29.34  2.03   30.37  0.01    10.24     18
# 497  RAJESHEXPO498      4,872.38  -50.67   0.5  -25.41  0.04     1.54     16
# 498       SPARC499      4,687.39  -27.34  1.53   -2.99  0.49    -2.45     11
# 499  EASEMYTRIP500      4,337.96  -13.88   1.5       -  0.03     0.08     17
#
#     Capability  b  c  d  e  f  g  Rank
# ...

# %%
csv1 = pd.read_csv("/content/main.csv")
csv2 = pd.read_csv("/content/mnist_test.csv")

data = pd.concat([csv1,csv2])
data
# Out:
#             Name    Market Cap  Alpha  Beta 5Y CAGR   D/E  EPS (Q)  SCORE  \
# 0       RELIANCE  16,45,671.87  -4.86     1   12.69   0.5    13.70   23.0
# 1            TCS  14,14,726.49   -4.4  0.61   12.27  0.09    34.21   23.0
# 2       HDFCBANK  12,98,771.00  -5.15   1.1    6.46     0    23.11   21.0
# 3     BHARTIARTL  10,26,583.48  23.02  0.64   26.47  2.04    25.54   26.0
# 4      ICICIBANK   8,82,070.18   7.85  1.27   18.21     0    18.26   26.0
# ...          ...           ...    ...   ...     ...   ...      ...    ...
# 9994         NaN           NaN    NaN   NaN     NaN   NaN      NaN    NaN
# 9995         NaN           NaN    NaN   NaN     NaN   NaN      NaN    NaN
# 9996         NaN           NaN    NaN   NaN     NaN   NaN      NaN    NaN
# 9997         NaN           NaN    NaN   NaN     NaN   NaN      NaN    NaN
# 9998         NaN           NaN    NaN   NaN     NaN   NaN      NaN    NaN
#
#      Capability    b  ...  0.658  0.659  0.660  0.661  0.662  0.663  0.664  \
# ...
